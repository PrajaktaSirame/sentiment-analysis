# %%
import networkx as nx
from matplotlib import pyplot as plt

# %%
import sys
# !{sys.executable} -m pip install networkx
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# jupyterlab-server 1.0.0 has requirement jsonschema>=3.0.1, but you'll have jsonschema 2.6.0 which is incompatible.
# You are using pip version 10.0.1, however version 21.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
G_symmetric = nx.Graph()

# %%
G_symmetric.add_edge('Messi','Ronaldo')
G_symmetric.add_edge('Messi','Pele')
G_symmetric.add_edge('Messi','Hugo')
G_symmetric.add_edge('Messi','Zindane')
G_symmetric.add_edge('Ronaldo','Pele')
G_symmetric.add_edge('Ronaldo','Hugo')
G_symmetric.add_edge('Ronaldo','Zindane')
G_symmetric.add_edge('Zindane','Pele')

# %%
nx.draw_networkx(G_symmetric)

# %%
G_asymmetric = nx.DiGraph()
G_asymmetric.add_edge('A','B')
G_asymmetric.add_edge('A','D')
G_asymmetric.add_edge('C','A')
G_asymmetric.add_edge('D','E')

# %%
nx.draw_networkx(G_asymmetric)

# %%
nx.spring_layout(G_asymmetric)
nx.draw_networkx(G_asymmetric)

# %%
G_weighted = nx.Graph()
G_weighted.add_edge('Messi','Ronaldo', weight=250)
G_weighted.add_edge('Messi','Pele', weight=80)
G_weighted.add_edge('Messi','Hugo', weight=11)
G_weighted.add_edge('Messi','Zindane', weight=100)
G_weighted.add_edge('Ronaldo','Pele', weight=4)
G_weighted.add_edge('Ronaldo','Hugo',weight=7)
G_weighted.add_edge('Ronaldo','Zindane', weight=1)
G_weighted.add_edge('Zindane','Pele',weight=1)

# %%
nx.draw_networkx(G_weighted)

# %% [markdown]
# # Network connectivity - Degree, Clustering Coefficient

# %%
nx.degree(G_symmetric, 'Zindane')
# Out:
# 3

# %%
nx.clustering(G_symmetric, 'Zindane')
# Out:
# 1.0

# %%
nx.shortest_path(G_symmetric, 'Zindane', 'Hugo')
# Out:
# ['Zindane', 'Messi', 'Hugo']

# %%
G_fb = nx.read_edgelist(r"C:\ALL-DATA\Social_Media_Analytics\facebook_short.txt", create_using = nx.Graph(), nodetype=int)

# %%
print(nx.info(G_fb))
# Out:
# Name:
# Type: Graph
# Number of nodes: 486
# Number of edges: 1772
# Average degree:   7.2922

# %%
nx.spring_layout(G_fb)
# Out:
# {0: array([0.08352932, 0.31139195]),
#  2: array([0.26994462, 0.33256679]),
#  3: array([-0.03031977,  0.24061455]),
#  4: array([0.31902551, 0.22681825]),
#  5: array([0.02684065, 0.16706313]),
#  6: array([0.27333705, 0.20060718]),
#  7: array([-0.1316617 ,  0.26120558]),
#  8: array([0.29042298, 0.4664    ]),
#  9: array([-0.05136464,  0.28762362]),
#  10: array([-0.08404371,  0.22747913]),
#  11: array([0.2302056 , 0.46643598]),
#  12: array([0.28715204, 0.44877676]),
#  13: array([-0.03537304,  0.33024521]),
#  14: array([0.24854599, 0.36054316]),
#  15: array([0.3441599 , 0.29846201]),
#  16: array([-0.00297599,  0.38566661]),
#  17: array([0.25967401, 0.38427578]),
#  18: array([0.20675242, 0.49599744]),
#  19: array([0.21537007, 0.37881912]),
#  20: array([0.27705518, 0.31849508]),
#  21: array([0.01823067, 0.27360298]),
#  22: array([-0.12502823,  0.21377076]),
#  23: array([0.10111587, 0.47251197]),
#  24: array([0.08053152, 0.0934767 ]),
# ...

# %%
pos = nx.spring_layout(G_fb)
betCent = nx.betweenness_centrality(G_fb, normalized=True, endpoints=True)
node_color = [20000.0 * G_fb.degree(v) for v in G_fb]
node_size =  [v * 10000 for v in betCent.values()]
plt.figure(figsize=(20,20))
nx.draw_networkx(G_fb, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')
# Out:
# (-1.0832080903981207,
#  0.6840090756735682,
#  -0.38767938732035734,
#  0.4192958462322727)
